# %%
#Python was named for the British comedy troupe Monty Python, so we'll make our first Python program a homage to their skit about Spam. this is a funny one
# Program -1 
spam_amount=0
print(spam_amount)

spam_amount=spam_amount+4
if spam_amount>0:
    print("But I don't want ANY spam!")
viking_song="Spam "*4
print(viking_song)

print("type of spam_amount is ",type(spam_amount))
print("type of viking_song is ",type(viking_song))

# %%
#program - 2 (Arithmetic operations)
hat_height_cm=25
my_height_cm=190

# How tall I am in meters wearing my hat
total_height_meters=hat_height_cm+my_height_cm/100
print("Height in meters ",total_height_meters, "?")

# the above doesn't work due to BODMAS, Parentheses are useful here. You can add it to force Python to evaluate sub-expressions in whatever order you want.

total_height_meters = (hat_height_cm + my_height_cm) / 100
print("Height in meters =", total_height_meters)

# %%
# Built-in function for working with numbers

print(min(1,2,3))
print(max(9,19,2))

print(abs(32))
print(abs(-32))

print(float(10))
print(int(3.33))
# They can even be called on strings!
print(int('807') + 1)

# %%
'''Alice, Bob and Carol have agreed to pool their Halloween candy and split it evenly among themselves. For the sake of their friendship, any candies left over will be smashed. For example, if they collectively bring home 91 candies, they'll take 30 each and smash 1.
Write an arithmetic expression below to calculate how many candies they must smash for a given haul.'''

alice_candies = 121
bob_candies=21
carol_candies=109

to_smash=(alice_candies+bob_candies+carol_candies)%3
print("Number of candies to smash ",to_smash)

# %%
# Help function in python 
help(round)
help(print)
help(abs)
help(round(-2.01))

# %%
#defining functions in python
def least_difference(a,b,c):
    diff1=abs(a-b)
    diff2=abs(b-c)
    diff3=abs(c-a)
    return min(diff1,diff2,diff3)
    return max(diff1,diff2,diff3)
print(least_difference(1,5,10))
print(least_difference(2,3,4),)
print(min(least_difference(1,5,10),least_difference(2,3,4)))

# %%
'''Functions that don't return¶
What would happen if we didn't include the return keyword in our function?'''

def least_difference(a, b, c):
    """Return the smallest difference between any two numbers
    among a, b and c.
    """
    diff1 = abs(a - b)
    diff2 = abs(b - c)
    diff3 = abs(a - c)
    min(diff1, diff2, diff3)
    
print(
    least_difference(1, 10, 100),
    least_difference(1, 10, 10),
    least_difference(5, 6, 7),
)

#Python allows us to define such functions. The result of calling them is the special value None. (This is similar to the concept of "null" in other languages.)

# %%
mystery = print()
print(mystery)

# %%
#Default Arguments
print(1,2,3, sep='<')

# %%
def greet(who='colin'):
    print("Hello, ",who)

greet()
greet(who='Alice')
greet('World')

# %%
#Here's something that's powerful, though it can feel very abstract at first. You can supply functions as arguments to other functions. Some example may make this clearer:

def mult_by_five(x):
    return 5*x

def call(fn, arg):
    return fn(arg)

def squared_call(fn, arg):
    return fn(fn(arg))

print ( call(mult_by_five,1),
       squared_call(mult_by_five,1), sep='\n', # \n is used to print the output in new line
       )

# %%
'''By default, max returns the largest of its arguments. But if we pass in a function using the optional key argument, it returns the argument x that maximizes key(x) (aka the 'argmax').'''
def mod_5(x):
    """Return the remainder of x after dividing by 5"""
    return x % 5

print(
    'Which number is biggest?',
    max(100, 51, 14),
    'Which number is the biggest modulo 5?',
    max(100, 51, 14, key=mod_5),
    sep='\n',
)

# %%
def to_smash(total_candies, n_friends=3):
    return total_candies % n_friends

print(to_smash(91))

# %%
#Booleans
x = True
print(x)
print(type(x))

# %%
def can_run_for_president(age):
    ''' Can someone of given age contest in elections'''
    ''' min age is 35 years'''
    return age >= 35
print("Can a 16 year old run for president? ", can_run_for_president(16))
print("Can a 35 year old run for president? ", can_run_for_president(35))

# %%
3==0
3==3.0
3=='3'

# %%
def is_odd(n):
    return n % 2 == 1
print("is 100 odd?", is_odd(100))
print("is 1 odd?", is_odd(1))

# %%
'''Combining Boolean Values¶
You can combine boolean values using the standard concepts of "and", "or", and "not". In fact, the words to do this are: and, or, and not.
With these, we can make our can_run_for_president function more accurate.'''

def can_run_for_president(age, is_citizen):
    return age>=35 and is_citizen
print("can a 16 year old non-citizen contest?", can_run_for_president(16, True))
print("can a 36 year old non-citizen contest?", can_run_for_president(36, False))
print("can a 40 year old citizen contest?", can_run_for_president(40, True))

# %%
# Conditional Statements

def inspect(x):
    if x==0:
        print("The number is zero.")
    elif x>0:
        print("The number is positive.")
    elif x<0:
        print("The number is negative.")
    else:
        print("This shouldn't ever happen.")
inspect(0)
inspect(5)
inspect(-1)

# %%
print(bool(1))
print(bool(0))
print(bool('asf'))
print(bool(''))
print(bool([]))
print(bool([1,2,3]))

# %%
if 0:
    print(0)
elif "spam":
    print("spam")

# %%
'''Many programming languages have sign available as a built-in function. Python doesn't, but we can define our own!

In the cell below, define a function called sign which takes a numerical argument and returns -1 if it's negative, 1 if it's positive, and 0 if it's 0.'''

def sign(x):
    if x<0:
        return -1
    elif x>0:
        return 1
    else:
        return 0
    
print(sign(-10))
print(sign(0))
print(sign(10))

# %%
def to_smash(total_candies):
    to_smash=total_candies%3
    print ("splitting ", total_candies, " candies among 3 friends")
    return total_candies%3

print(to_smash(91))

# %%
def to_smash(total_candies):
    if total_candies==1:
        print("Splitting 1 candy among 3 friends")
    else:
        print ("splitting ", total_candies, " candies among 3 friends")

print(to_smash(91))
print(to_smash(1))

# %%
# In the cell below, define a function called sign which takes a numerical argument and returns -1 if it's negative, 
# 1 if it's positive, and 0 if it's 0.

def sign(x):
    if x<0:
        return -1
    elif x>0:
        return 1
    else:
        return 0
    
print(sign(10))
print(sign(-32))
print(sign(0))

# %%
#Modify the definition in the cell below to correct the grammar of our print statement. 
# (If there's only one candy, we should use the singular "candy" instead of the plural "candies")

def to_smash(total_candies):
    if total_candies==1:
        print("splitting one candy among 3 friends")
    else:
        print("splitting",total_candies," candies among 3 friends")

print(to_smash(91))
print(to_smash(1))
print(to_smash(9))

print("Splitting", total_candies, "candy" if total_candies == 1 else "candies")

# %%
'''In the tutorial, we talked about deciding whether we're prepared for the weather. I said that I'm safe from today's weather if...
    I have an umbrella...
    or if the rain isn't too heavy and I have a hood...
    otherwise, I'm still fine unless it's raining and it's a workday
To prove that prepared_for_weather is buggy, come up with a set of inputs where either:
    the function returns False (but should have returned True), or
    the function returned True (but should have returned False).'''

def prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday):
    return have_umbrella or (rain_level < 5 and have_hood) or (is_workday)

have_umbrella = False
rain_level=10
have_hood=False
is_workday=False

actual=prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday)
print(actual)

# %%
def is_negative(number):
    pass
    return number < 0

# %%
def onionless(ketchup,mustard,onion):
    '''return wether the customer doesn't want onions'''
    return ketchup and mustard and onion
    return not onion

def want_all_toppings(ketchup,mustard,onion):
    '''return wether the customer wants all the toppings'''
    return ketchup and mustard and onion
    pass

def wants_plain_hotdog(ketchup,mustard,onion):
    '''return wether customer wants a plain hotdog'''
    return not ketchup and not mustard and not onion
    pass

def exactly_one_sauce(ketchup,mustard,onion):
    '''return wether the customer wants exactly one sauce'''
    pass
    return (ketchup and not mustard ) or (mustard and not ketchup)

'''Weve seen that calling bool() on an integer returns False if its equal to 0 and True otherwise. What happens if we call int() on a bool? Try it out in the notebook cell below.
Can you take advantage of this to write a succinct function that corresponds to the English sentence "does the customer want exactly one topping?"?'''

def exactly_one_topping(ketchup, mustard, onion):
    '''return wether the customer wants exactly one topping'''
    return int(ketchup) + int(mustard) + int(onion) == 1

# %%
def should_hit(dealer_total, player_total, player_low_total, player_high_total):
      """Return True if the player should hit (request another card) given the current game
    state, or False if the player should stay.
    When calculating a hand's total value, we count aces as "high" (with value 11) if doing so
    doesn't bring the total above 21, otherwise we count them as low (with value 1). 
    For example, if the player's hand is {A, A, A, 7}, we will count it as 11 + 1 + 1 + 7,
    and therefore set player_total=20, player_low_aces=2, player_high_aces=1.
    """
    if player_total <=21:
      current_total=player_high_total
    else:
      current_total=player_low_total

# %%
# Strings in python

print('my name\'s pluto')
print ('I love \'Flowers\'')
print('Hello\nWorld')
print("hello", end=' ')
print("pluto")

'''Strings are sequences
Strings can be thought of as sequences of characters. Almost everything we've seen 
that we can do to a list, we can also do to a string.'''

#Indexing
Planet='Pluto'
Planet[0]

#Slicing
Planet[-1]

Planet[-2:]

Planet[1:4]

Planet[1:5:2]

len(Planet)

[char + '!' for char in Planet]

#Drawback compared to Lists
    #Immutability, so cannot append

#String methods: 

claim='pluto is an extinct planet'

claim.upper()

claim='PLUTO IS AN EXTINCT PLANET!'
claim.lower()

claim.index('PLAN')

claim.startswith('S')

claim.endswith('PLANET')

claim.split()

datestr='2026-06-08'

year,month,day=datestr.split('-')
print(year) 
print(month)
print(day)

'/'.join([year,month,day])

'😃'.join([year,month,day])

concat='pluto'+' we miss you'
print(concat)

position=9

planet="pluto"

joined=planet+" is the "+str(position)+"th planet,  "+claim
print(joined)

"{}, you'll always be my {}th planet".format(planet, position)

#Notice how we didn't even have to call str() to convert position from an int. format() takes care of that for us.

# %%
'''If that was all that format() did, it would still be incredibly useful. 
But as it turns out, it can do a lot more. Here's just a taste:'''

planet='pluto'
pluto_mass = 1.303 * 10**22
earth_mass = 5.9722 * 10**24
population = 52910390

"{} weighs about {:.2} kilograms ({:.3%} of Earth's mass). It is home to {:,} Plutonians.".format(
    planet, pluto_mass, pluto_mass / earth_mass, population,)


# Referring to format() arguments by index, starting from 0

s='''"Pluto is a {0}.
No, its a {1}.
{0}!
{1}!'''.format('planet','dwarf planet')
print(s)

# %%
'''Dictionaries
Dictionaries are a built-in Python data structure for mapping keys to values.

numbers = {'one':1, 'two':2, 'three':3}''' 

numbers = {'one':1, 'two':2, 'three':3}

numbers['two']

numbers['four']=4

numbers

'''Python has dictionary comprehensions with a syntax similar to the list comprehensions
 we saw in the previous tutorial.'''

planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

planet_initial={planet: planet[0] for planet in planets}
planet_initial

'Saturn' in planet_initial

for k in numbers:
    print("{}={}".format(k, numbers[k]))

'''We can access a collection of all the keys or all the values with dict.keys() and dict.values(), respectively.'''
' '.join(sorted(planet_initial.values()))

'''The very useful dict.items() method lets us iterate over the keys and values of a dictionary simultaneously. 
(In Python jargon, an item refers to a key, value pair)'''

for planet, initial in planet_initial.items():
    print("{} begins with {}".format(planet, initial))

# %%
# Strings and dictionary exercises

'''1. There is a saying that "Data scientists spend 80% of their time cleaning data, and 
20% of their time complaining about cleaning data."
 Let's see if you can write a function to help clean US zip code data.
 Given a string, it should return whether or not that string represents a valid zip code. 
    For our purposes, a valid zip code is any string consisting of exactly 5 digits.

HINT: str has a method that will be useful here. Use help(str) to review a list of string methods.'''

def is_valid_zip(zip_code):
    return len(zip_code)==5 and zip_code.isdigit()

print(is_valid_zip('13456'))
print(is_valid_zip('1345'))


'''A researcher has gathered thousands of news articles. But she wants to focus her attention on articles including a specific word. Complete the function below to help her filter her list of articles.

Your function should meet the following criteria:

Do not include documents where the keyword string shows up only as a part of a larger word. For example, if she were looking for the keyword “closed”, you would not include the string “enclosed.”
She does not want you to distinguish upper case from lower case letters. So the phrase “Closed the case.” would be included when the keyword is “closed”
Do not let periods or commas affect what is matched. “It is closed.” would be included when the keyword is “closed”. But you can assume there are no other types of punctuation.'''


def word_search(doc_list,keyword):
    indices=[]
     
    for i, doc in enumerate(doc_list):
       tokens=doc.split()

       normalized=[token.rstrip('.,').lower() for token in tokens]

       if keyword.lower in normalized:
           indices.append(i)

    return indices

# %%
# modules in Python

#1. Math

import math
print("its math module, it has type{}".format(type(math)))

print(dir(math))

print("pi to 4 significant digits is {:.4}".format(math.pi))

math.log(32,2)

help(math.log)

help(math)


'''Wouldn't it be great if we could refer to all the variables in the math module by themselves? i.e.
 if we could just refer to pi instead of math.pi or mt.pi? Good news: we can do that.'''

from math import *
print(pi,log(32,2))

#import * makes all the module's variables directly accessible to you (without any dotted prefix)

from math import *
from numpy import *
print(pi, log(32, 2))

'''What has happened? It worked before!
These kinds of "star imports" can occasionally lead to weird, difficult-to-debug situations.
The problem in this case is that the math and numpy modules both have functions called log, 
but they have different semantics. Because we import from numpy second, its log overwrites (or "shadows") the log variable we imported from math.
A good compromise is to import only the specific things we'll need from each module:'''

from math import pi,log
from numpy import log as np_log
print(pi, log(32,2), np_log(32,2))

'''Submodules
We've seen that modules contain variables which can refer to functions or values. 
Something to be aware of is that they can also have variables referring to other modules.'''

import numpy
print("numpy.random is a", type(numpy.random))
print("it contains names such as...",
      dir(numpy.random)[-15:]
     )
#So if we import numpy as above, then calling a function in the random "submodule" will require two dots.

rolls=numpy.random.randint(low=1, high=7, size=10)
print(rolls)
# Out:
# its math module, it has type<class 'module'>
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
# pi to 4 significant digits is 3.142
# Help on built-in function log in module math:
#
# log(...)
#     log(x, [base=math.e])
#     Return the logarithm of x to the given base.
#
#     If the base is not specified, returns the natural logarithm (base e) of x.
#
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
# ...
